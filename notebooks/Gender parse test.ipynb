# %% [markdown]
# # Parsing gender from names with an API

# %% [markdown]
# Genderize.io determines the gender of a first name. Use the API for analytics, ad targeting, user segmenting etc. It utilizes big datasets of information, from user profiles across major social networks and exposes this data through its API. The response includes a certainty factor as well.

# %%
import pandas as pd

# %%
# %load ../parse_gender.py
import requests
import json


api_url_base = 'https://api.genderize.io/'

def get_gender(firstname):
    request_url = '{}?name={}'.format(api_url_base, firstname)
    response = requests.get(request_url)
    
    if response.status_code == 200:
        return (response.json())
    else:
        print('[!] HTTP {0} looking up name [{1}]'.format(response.status_code, firstname))
        return None

# %%
get_gender('Steve')
# Out:
# {'name': 'Steve', 'gender': 'male', 'probability': 1, 'count': 3965}

# %%
recurse = pd.read_csv('../recursecenter.csv')

# %%
recurse.columns = ['repo', 'username', 'contributions', 'avatar_url', 'profile_url', 'real_name']

# %%
recurse.head()
# Out:
#           repo      username  contributions  \
# 0       hs-cli  davidbalbert              2
# 1  webstack.jl  danielmendel             63
# 2  webstack.jl    astrieanna             36
# 3  webstack.jl    zachallaun             19
# 4  webstack.jl       chuckha              8
#
#                                           avatar_url  \
# 0  https://avatars2.githubusercontent.com/u/12335...
# 1  https://avatars3.githubusercontent.com/u/30420...
# 2  https://avatars3.githubusercontent.com/u/12053...
# 3  https://avatars0.githubusercontent.com/u/50393...
# 4  https://avatars0.githubusercontent.com/u/98927...
#
#                                  profile_url       real_name
# 0  https://api.github.com/users/davidbalbert    David Albert
# 1  https://api.github.com/users/danielmendel  Daniel Espeset
# 2    https://api.github.com/users/astrieanna     Leah Hanson
# 3    https://api.github.com/users/zachallaun     Zach Allaun
# 4       https://api.github.com/users/chuckha        Chuck Ha

# %%
recurse.loc[0]['real_name'].split(' ')[0]
# Out:
# 'David'

# %%
recurse.head(3)
# Out:
#           repo      username  contributions  \
# 0       hs-cli  davidbalbert              2
# 1  webstack.jl  danielmendel             63
# 2  webstack.jl    astrieanna             36
#
#                                           avatar_url  \
# 0  https://avatars2.githubusercontent.com/u/12335...
# 1  https://avatars3.githubusercontent.com/u/30420...
# 2  https://avatars3.githubusercontent.com/u/12053...
#
#                                  profile_url       real_name
# 0  https://api.github.com/users/davidbalbert    David Albert
# 1  https://api.github.com/users/danielmendel  Daniel Espeset
# 2    https://api.github.com/users/astrieanna     Leah Hanson

# %%
recurse.shape
# Out:
# (160, 7)

# %%
## Split first name from real_name, look up gender

gender_list = list()

for name in recurse['real_name'].unique():
    if type(name) == str: # don't call on NaN values (which are float - why?)
        first_name = name.split(' ')[0]
        gender_result = get_gender(first_name)
        gender_result['real_name'] = name # add real name back to dictionary
        gender_list.append(gender_result)

# %% [markdown]
# In the function above, we should use a set or unique method to only not duplicate lookups.

# %%
# Record with no value for real_name
recurse['real_name'][12]
# Out:
# nan

# %%
type(recurse['real_name'][12]) == str
# Out:
# False

# %%
recurse['real_name'][12]

# %%
gender_list[0]
# Out:
# {'name': 'David',
#  'gender': 'male',
#  'probability': 1,
#  'count': 12593,
#  'real_name': 'David Albert'}

# %%
genders = pd.DataFrame(gender_list)

# %%
genders.head(5)
# Out:
#      count  gender    name  probability       real_name
# 0  12593.0    male   David         1.00    David Albert
# 1   8180.0    male  Daniel         1.00  Daniel Espeset
# 2    904.0  female    Leah         1.00     Leah Hanson
# 3    673.0    male    Zach         0.99     Zach Allaun
# 4    512.0    male   Chuck         0.99        Chuck Ha

# %%
recurse.head()
# Out:
#           repo      username  contributions  \
# 0       hs-cli  davidbalbert              2
# 1  webstack.jl  danielmendel             63
# 2  webstack.jl    astrieanna             36
# 3  webstack.jl    zachallaun             19
# 4  webstack.jl       chuckha              8
#
#                                           avatar_url  \
# 0  https://avatars2.githubusercontent.com/u/12335...
# 1  https://avatars3.githubusercontent.com/u/30420...
# 2  https://avatars3.githubusercontent.com/u/12053...
# 3  https://avatars0.githubusercontent.com/u/50393...
# 4  https://avatars0.githubusercontent.com/u/98927...
#
#                                  profile_url       real_name
# 0  https://api.github.com/users/davidbalbert    David Albert
# 1  https://api.github.com/users/danielmendel  Daniel Espeset
# 2    https://api.github.com/users/astrieanna     Leah Hanson
# 3    https://api.github.com/users/zachallaun     Zach Allaun
# 4       https://api.github.com/users/chuckha        Chuck Ha

# %%
# Sanity check
print(genders.shape)
print(recurse.shape)
# Out:
# (160, 5)
# (160, 6)

# %%
# This is unnecessary...
recurse_gendered = recurse.join(genders, lsuffix='_x')

# %%
recurse_gendered.head()
# Out:
#           repo      username  contributions  \
# 0       hs-cli  davidbalbert              2
# 1  webstack.jl  danielmendel             63
# 2  webstack.jl    astrieanna             36
# 3  webstack.jl    zachallaun             19
# 4  webstack.jl       chuckha              8
#
#                                           avatar_url  \
# 0  https://avatars2.githubusercontent.com/u/12335...
# 1  https://avatars3.githubusercontent.com/u/30420...
# 2  https://avatars3.githubusercontent.com/u/12053...
# 3  https://avatars0.githubusercontent.com/u/50393...
# 4  https://avatars0.githubusercontent.com/u/98927...
#
#                                  profile_url     real_name_x    count  gender  \
# 0  https://api.github.com/users/davidbalbert    David Albert  12593.0    male
# 1  https://api.github.com/users/danielmendel  Daniel Espeset   8180.0    male
# 2    https://api.github.com/users/astrieanna     Leah Hanson    904.0  female
# 3    https://api.github.com/users/zachallaun     Zach Allaun    673.0    male
# 4       https://api.github.com/users/chuckha        Chuck Ha    512.0    male
#
#      name  probability       real_name
# 0   David         1.00    David Albert
# 1  Daniel         1.00  Daniel Espeset
# 2    Leah         1.00     Leah Hanson
# 3    Zach         0.99     Zach Allaun
# 4   Chuck         0.99        Chuck Ha

# %%
recurse_gendered.shape
# Out:
# (160, 11)

# %% [markdown]
# ### to-do:
# Since the same people will be likely to contribute to multiple repos, we should work out how to de-duplicate the names before looking up on the API. (Maybe using set or unique?)

# %%
# simulate a list with no duplicates, as would happen when looking up names only once
g2 = genders.drop_duplicates()

# %%
df2 = pd.merge(recurse, g2[['real_name', 'gender', 'probability']], on='real_name')

# %%
df2.head(30)
# Out:
#             repo         username  contributions  \
# 0         hs-cli     davidbalbert              2
# 1   blaggregator     davidbalbert             12
# 2      community     davidbalbert            335
# 3          proxy     davidbalbert             58
# 4        RSVPBot     davidbalbert             84
# 5       ca-tools     davidbalbert             11
# 6    webstack.jl     danielmendel             63
# 7    webstack.jl       astrieanna             36
# 8    webstack.jl       zachallaun             19
# 9   blaggregator       zachallaun              1
# 10     community       zachallaun            745
# 11         proxy       zachallaun             59
# 12       RSVPBot       zachallaun             32
# 13   webstack.jl          chuckha              8
# 14   webstack.jl         ncollins              4
# 15   webstack.jl        maxlikely              3
# 16   webstack.jl  StefanKarpinski              2
# 17   webstack.jl            jroes              1
# 18  blaggregator            sursh            278
# 19  blaggregator          kenyavs             10
# 20       RSVPBot     alexandrinaw             38
# 21  blaggregator        punchagan            249
# 22  blaggregator        stanzheng              5
# 23  blaggregator          akaptur              3
# 24  blaggregator     porterjamesj              3
# 25       RSVPBot     porterjamesj              1
# 26  blaggregator        santialbo              3
# 27  blaggregator          strugee              2
# 28     community          strugee              1
# 29  blaggregator           danluu              2
#
#                                            avatar_url  \
# 0   https://avatars2.githubusercontent.com/u/12335...
# 1   https://avatars2.githubusercontent.com/u/12335...
# 2   https://avatars2.githubusercontent.com/u/12335...
# 3   https://avatars2.githubusercontent.com/u/12335...
# 4   https://avatars2.githubusercontent.com/u/12335...
# 5   https://avatars2.githubusercontent.com/u/12335...
# 6   https://avatars3.githubusercontent.com/u/30420...
# 7   https://avatars3.githubusercontent.com/u/12053...
# 8   https://avatars0.githubusercontent.com/u/50393...
# 9   https://avatars0.githubusercontent.com/u/50393...
# 10  https://avatars0.githubusercontent.com/u/50393...
# 11  https://avatars0.githubusercontent.com/u/50393...
# 12  https://avatars0.githubusercontent.com/u/50393...
# 13  https://avatars0.githubusercontent.com/u/98927...
# 14  https://avatars1.githubusercontent.com/u/60729...
# 15  https://avatars1.githubusercontent.com/u/12370...
# 16  https://avatars2.githubusercontent.com/u/15359...
# 17  https://avatars0.githubusercontent.com/u/27847...
# 18  https://avatars1.githubusercontent.com/u/71959...
# 19  https://avatars2.githubusercontent.com/u/14684...
# 20  https://avatars3.githubusercontent.com/u/43933...
# 21  https://avatars0.githubusercontent.com/u/31567...
# 22  https://avatars1.githubusercontent.com/u/36839...
# 23  https://avatars2.githubusercontent.com/u/18577...
# 24  https://avatars2.githubusercontent.com/u/25325...
# 25  https://avatars2.githubusercontent.com/u/25325...
# 26  https://avatars3.githubusercontent.com/u/15575...
# 27  https://avatars0.githubusercontent.com/u/91117...
# 28  https://avatars0.githubusercontent.com/u/91117...
# 29  https://avatars1.githubusercontent.com/u/15713...
#
#                                      profile_url         real_name  gender  \
# 0      https://api.github.com/users/davidbalbert      David Albert    male
# 1      https://api.github.com/users/davidbalbert      David Albert    male
# 2      https://api.github.com/users/davidbalbert      David Albert    male
# 3      https://api.github.com/users/davidbalbert      David Albert    male
# 4      https://api.github.com/users/davidbalbert      David Albert    male
# 5      https://api.github.com/users/davidbalbert      David Albert    male
# 6      https://api.github.com/users/danielmendel    Daniel Espeset    male
# 7        https://api.github.com/users/astrieanna       Leah Hanson  female
# 8        https://api.github.com/users/zachallaun       Zach Allaun    male
# 9        https://api.github.com/users/zachallaun       Zach Allaun    male
# 10       https://api.github.com/users/zachallaun       Zach Allaun    male
# 11       https://api.github.com/users/zachallaun       Zach Allaun    male
# 12       https://api.github.com/users/zachallaun       Zach Allaun    male
# 13          https://api.github.com/users/chuckha          Chuck Ha    male
# 14         https://api.github.com/users/ncollins      Nick Collins    male
# 15        https://api.github.com/users/maxlikely             David    male
# 16  https://api.github.com/users/StefanKarpinski  Stefan Karpinski    male
# 17            https://api.github.com/users/jroes     Jonathan Roes    male
# 18            https://api.github.com/users/sursh               NaN  female
# 19          https://api.github.com/users/kenyavs               NaN  female
# 20     https://api.github.com/users/alexandrinaw               NaN  female
# 21        https://api.github.com/users/punchagan  Puneeth Chaganti    male
# 22        https://api.github.com/users/stanzheng     Stanley Zheng    male
# 23          https://api.github.com/users/akaptur    Allison Kaptur  female
# 24     https://api.github.com/users/porterjamesj    James J Porter    male
# 25     https://api.github.com/users/porterjamesj    James J Porter    male
# 26        https://api.github.com/users/santialbo        Santi Albo    male
# 27          https://api.github.com/users/strugee         AJ Jordan    male
# 28          https://api.github.com/users/strugee         AJ Jordan    male
# 29           https://api.github.com/users/danluu           Dan Luu    male
#
#     probability
# 0          1.00
# 1          1.00
# 2          1.00
# 3          1.00
# 4          1.00
# 5          1.00
# 6          1.00
# 7          1.00
# 8          0.99
# 9          0.99
# 10         0.99
# 11         0.99
# 12         0.99
# 13         0.99
# 14         0.99
# 15         1.00
# 16         1.00
# 17         1.00
# 18         0.91
# 19         0.91
# 20         0.91
# 21         1.00
# 22         0.96
# 23         1.00
# 24         0.99
# 25         0.99
# 26         0.85
# 27         0.81
# 28         0.81
# 29         0.98

# %% [markdown]
# When the name has a NaN value it looks like genderize is being passed 'nan' and guessing that the name is female.

# %%
## Split first name from real_name, look up gender

gender_list = list()

for name in recurse['real_name'].unique():
    if type(name) == str:
        first_name = name.split(' ')[0]
        gender_result = get_gender(first_name)
        gender_result['real_name'] = name # add real name back to dictionary
        gender_list.append(gender_result)
