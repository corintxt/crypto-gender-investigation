# %%
# %load clear_get_repo_contributions.py
import json
import requests
import csv
import config

session = requests.session()
## Comment out Tor proxy for now.
# session.proxies = {}
# session.proxies['http'] = 'socks5h://localhost:9050'
# session.proxies['https'] = 'socks5h://localhost:9050'

API_TOKEN = config.api_key

api_url_base = 'https://api.github.com/'
headers = {'Content-Type': 'application/json',
           'User-Agent': 'python-requests/3.6.1',
           'Accept': 'application/vnd.github.v3+json',
           'Authorization': 'token %s' % API_TOKEN}


def get_repos(orgname):
    api_url = '{}orgs/{}/repos'.format(api_url_base, orgname)
    # use session.get instead of request
    response = session.get(api_url, headers=headers)

    if response.status_code == 200:
        return (response.json())
    else:
        print('[!] HTTP {0} calling [{1}]'.format(response.status_code, api_url))
        return None


def get_contributors(repo):
    name = repo['name']
    contrib_url = repo['contributors_url']
    
    response = session.get(contrib_url, headers=headers)

    if response.status_code == 200:
        return (
            # returns `contribution_response`
            {'name': name,
             'data': response.json()}
        )
    else:
        print('[!] HTTP {0} calling repo [{1}]'.format(response.status_code, contrib_url))
        return None


def build_contribution_list(contribution_response):
    all_repo_contributions = list()

    for i in range(0,len(contribution_response['data'])):
        ctr = dict()
        ctr["repo"] = contribution_response['name']
        ctr["username"] = contribution_response['data'][i]['login']
        ctr["contributions"] = contribution_response['data'][i]['contributions']
        ctr["avatar_url"] = contribution_response['data'][i]['avatar_url']
        ctr["profile_url"] = contribution_response['data'][i]['url']
        all_repo_contributions.append(ctr)
    
    return all_repo_contributions


def lookup_human_name(profile_url):    
    response = session.get(profile_url, headers=headers)

    if response.status_code == 200:
        return (response.json()['name'])
    else:
        print('[!] HTTP {0} looking up user [{1}]'.format(response.status_code, profile_url))
        return None


def append_list_to_csv(mylist, output_file):
    with open(output_file, 'a') as myfile:
        wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
        wr.writerow(mylist)

# define list variable outside of get_all_contributions function
all_org_contributions = list()
  
def get_all_contributions(org):
    print("Retrieving list of all repos for {}".format(org))
    repos = get_repos(org)

    for repo in repos:
        print("Building contributor commit list for {}".format(repo['full_name']))
        contributors = get_contributors(repo)
        contribution_list = build_contribution_list(contributors)
        all_org_contributions.append(contribution_list)

    # new API call to add real names to dictionary
    print("Matching real names against contributor usernames...")
    for i in range (0, len(all_org_contributions)):
        print("Searching repo {} of {}".format(i,len(all_org_contributions)))
        for j in range (0, len(all_org_contributions[i])):
            human_name = lookup_human_name(all_org_contributions[i][j]['profile_url'])
            all_org_contributions[i][j]['name'] = human_name

    print("Contribution list complete!")

############

## This part isn't in the right format
    print("Writing to file.")

    file_name = "{}.csv".format(org)
    flat_contributions = [item for sublist in all_org_contributions for item in sublist]
    ## Do this row by row.
    for item in flat_contributions:
        append_list_to_csv(item, file_name)

    print("Contributor list saved as {}".format(file_name))

# %%
get_all_contributions('recursecenter')
# Out:
# Retrieving list of all repos for recursecenter
# Building contributor commit list for recursecenter/hs-cli
# Building contributor commit list for recursecenter/webstack.jl
# Building contributor commit list for recursecenter/blaggregator
# Building contributor commit list for recursecenter/community
# Building contributor commit list for recursecenter/terminal_snake
# Building contributor commit list for recursecenter/sprockets-commonjs
# Building contributor commit list for recursecenter/proxy
# Building contributor commit list for recursecenter/eventmachine
# Building contributor commit list for recursecenter/heroku-buildpack-ruby
# Building contributor commit list for recursecenter/sprockets
# Building contributor commit list for recursecenter/recurse-lisp-workshop
# Building contributor commit list for recursecenter/RSVPBot
# Building contributor commit list for recursecenter/ca-tools
# Building contributor commit list for recursecenter/coding-bee
# Matching real names against contributor usernames...
# Searching repo 0 of 14
# Searching repo 1 of 14
# Searching repo 2 of 14
# Searching repo 3 of 14
# Searching repo 4 of 14
# Searching repo 5 of 14
# Searching repo 6 of 14
# Searching repo 7 of 14
# Searching repo 8 of 14
# Searching repo 9 of 14
# Searching repo 10 of 14
# Searching repo 11 of 14
# Searching repo 12 of 14
# Searching repo 13 of 14
# Contribution list complete!
# Writing to file.
# Contributor list saved as recursecenter.csv

# %%
all_org_contributions
# Out:
# [[{'repo': 'hs-cli',
#    'username': 'zachallaun',
#    'contributions': 51,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/503938?v=4',
#    'profile_url': 'https://api.github.com/users/zachallaun',
#    'name': 'Zach Allaun'},
#   {'repo': 'hs-cli',
#    'username': 'davidbalbert',
#    'contributions': 2,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/123350?v=4',
#    'profile_url': 'https://api.github.com/users/davidbalbert',
#    'name': 'David Albert'}],
#  [{'repo': 'webstack.jl',
#    'username': 'danielmendel',
#    'contributions': 63,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/304202?v=4',
#    'profile_url': 'https://api.github.com/users/danielmendel',
#    'name': 'Daniel Espeset'},
#   {'repo': 'webstack.jl',
#    'username': 'astrieanna',
#    'contributions': 36,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/1205394?v=4',
#    'profile_url': 'https://api.github.com/users/astrieanna',
#    'name': 'Leah Hanson'},
#   {'repo': 'webstack.jl',
#    'username': 'zachallaun',
#    'contributions': 19,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/503938?v=4',
#    'profile_url': 'https://api.github.com/users/zachallaun',
#    'name': 'Zach Allaun'},
#   {'repo': 'webstack.jl',
#    'username': 'chuckha',
#    'contributions': 8,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/98927?v=4',
#    'profile_url': 'https://api.github.com/users/chuckha',
#    'name': 'Chuck Ha'},
#   {'repo': 'webstack.jl',
#    'username': 'ncollins',
#    'contributions': 4,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/607298?v=4',
#    'profile_url': 'https://api.github.com/users/ncollins',
#    'name': 'Nick Collins'},
#   {'repo': 'webstack.jl',
#    'username': 'maxlikely',
#    'contributions': 3,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/1237055?v=4',
#    'profile_url': 'https://api.github.com/users/maxlikely',
#    'name': 'David'},
#   {'repo': 'webstack.jl',
#    'username': 'StefanKarpinski',
#    'contributions': 2,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/153596?v=4',
#    'profile_url': 'https://api.github.com/users/StefanKarpinski',
#    'name': 'Stefan Karpinski'},
#   {'repo': 'webstack.jl',
#    'username': 'jroes',
#    'contributions': 1,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/27847?v=4',
#    'profile_url': 'https://api.github.com/users/jroes',
#    'name': 'Jonathan Roes'}],
#  [{'repo': 'blaggregator',
#    'username': 'sursh',
#    'contributions': 278,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/719590?v=4',
#    'profile_url': 'https://api.github.com/users/sursh',
#    'name': None},
#   {'repo': 'blaggregator',
#    'username': 'punchagan',
#    'contributions': 249,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/315678?v=4',
#    'profile_url': 'https://api.github.com/users/punchagan',
#    'name': 'Puneeth Chaganti'},
#   {'repo': 'blaggregator',
#    'username': 'davidbalbert',
#    'contributions': 12,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/123350?v=4',
#    'profile_url': 'https://api.github.com/users/davidbalbert',
#    'name': 'David Albert'},
#   {'repo': 'blaggregator',
#    'username': 'kenyavs',
#    'contributions': 10,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/1468421?v=4',
#    'profile_url': 'https://api.github.com/users/kenyavs',
#    'name': None},
#   {'repo': 'blaggregator',
#    'username': 'stanzheng',
#    'contributions': 5,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/3683993?v=4',
#    'profile_url': 'https://api.github.com/users/stanzheng',
#    'name': 'Stanley Zheng'},
#   {'repo': 'blaggregator',
#    'username': 'akaptur',
#    'contributions': 3,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/1857780?v=4',
#    'profile_url': 'https://api.github.com/users/akaptur',
#    'name': 'Allison Kaptur'},
#   {'repo': 'blaggregator',
#    'username': 'porterjamesj',
#    'contributions': 3,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/2532521?v=4',
#    'profile_url': 'https://api.github.com/users/porterjamesj',
#    'name': 'James J Porter'},
#   {'repo': 'blaggregator',
#    'username': 'santialbo',
#    'contributions': 3,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/1557563?v=4',
#    'profile_url': 'https://api.github.com/users/santialbo',
#    'name': 'Santi Albo'},
#   {'repo': 'blaggregator',
#    'username': 'strugee',
#    'contributions': 2,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/911174?v=4',
#    'profile_url': 'https://api.github.com/users/strugee',
#    'name': 'AJ Jordan'},
#   {'repo': 'blaggregator',
#    'username': 'danluu',
#    'contributions': 2,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/157136?v=4',
#    'profile_url': 'https://api.github.com/users/danluu',
#    'name': 'Dan Luu'},
#   {'repo': 'blaggregator',
#    'username': 'PuercoPop',
#    'contributions': 2,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/387111?v=4',
#    'profile_url': 'https://api.github.com/users/PuercoPop',
#    'name': 'Javier Olaechea'},
#   {'repo': 'blaggregator',
#    'username': 'pnf',
#    'contributions': 2,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/1265645?v=4',
#    'profile_url': 'https://api.github.com/users/pnf',
#    'name': 'Peter Fraenkel'},
#   {'repo': 'blaggregator',
#    'username': 'alliejones',
#    'contributions': 1,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/560881?v=4',
#    'profile_url': 'https://api.github.com/users/alliejones',
#    'name': 'Allie Jones'},
#   {'repo': 'blaggregator',
#    'username': 'nnja',
#    'contributions': 1,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/2030983?v=4',
#    'profile_url': 'https://api.github.com/users/nnja',
#    'name': 'Nina Zakharenko'},
#   {'repo': 'blaggregator',
#    'username': 'graue',
#    'contributions': 1,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/1730853?v=4',
#    'profile_url': 'https://api.github.com/users/graue',
#    'name': 'Scott Feeney'},
#   {'repo': 'blaggregator',
#    'username': 'thomasboyt',
#    'contributions': 1,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/579628?v=4',
#    'profile_url': 'https://api.github.com/users/thomasboyt',
#    'name': 'Thomas Boyt'},
#   {'repo': 'blaggregator',
#    'username': 'zachallaun',
#    'contributions': 1,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/503938?v=4',
#    'profile_url': 'https://api.github.com/users/zachallaun',
#    'name': 'Zach Allaun'},
#   {'repo': 'blaggregator',
#    'username': 'esommer',
#    'contributions': 1,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/1130700?v=4',
#    'profile_url': 'https://api.github.com/users/esommer',
#    'name': 'Emily Sommer'}],
#  [{'repo': 'community',
#    'username': 'zachallaun',
#    'contributions': 745,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/503938?v=4',
#    'profile_url': 'https://api.github.com/users/zachallaun',
#    'name': 'Zach Allaun'},
#   {'repo': 'community',
#    'username': 'davidbalbert',
#    'contributions': 335,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/123350?v=4',
#    'profile_url': 'https://api.github.com/users/davidbalbert',
#    'name': 'David Albert'},
#   {'repo': 'community',
#    'username': 'madhuvishy',
#    'contributions': 63,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/621621?v=4',
#    'profile_url': 'https://api.github.com/users/madhuvishy',
#    'name': 'Madhumitha Viswanathan'},
#   {'repo': 'community',
#    'username': 'surenm',
#    'contributions': 61,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/389694?v=4',
#    'profile_url': 'https://api.github.com/users/surenm',
#    'name': 'Surendran Mahendran'},
#   {'repo': 'community',
#    'username': 'jollysonali',
#    'contributions': 11,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/742327?v=4',
#    'profile_url': 'https://api.github.com/users/jollysonali',
#    'name': 'Sonali Sridhar'},
#   {'repo': 'community',
#    'username': 'lord',
#    'contributions': 4,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/1976330?v=4',
#    'profile_url': 'https://api.github.com/users/lord',
#    'name': 'Robert Lord'},
#   {'repo': 'community',
#    'username': 'himerzi',
#    'contributions': 3,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/835088?v=4',
#    'profile_url': 'https://api.github.com/users/himerzi',
#    'name': 'Michael Detmold'},
#   {'repo': 'community',
#    'username': 'pietromenna',
#    'contributions': 3,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/840539?v=4',
#    'profile_url': 'https://api.github.com/users/pietromenna',
#    'name': 'Pietro Menna'},
#   {'repo': 'community',
#    'username': 'brendannee',
#    'contributions': 2,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/96217?v=4',
#    'profile_url': 'https://api.github.com/users/brendannee',
#    'name': 'Brendan Nee'},
#   {'repo': 'community',
#    'username': 'strugee',
#    'contributions': 1,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/911174?v=4',
#    'profile_url': 'https://api.github.com/users/strugee',
#    'name': 'AJ Jordan'},
#   {'repo': 'community',
#    'username': 'HiroAgustin',
#    'contributions': 1,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/1458873?v=4',
#    'profile_url': 'https://api.github.com/users/HiroAgustin',
#    'name': 'Agustín Díaz'},
#   {'repo': 'community',
#    'username': 'jasonaowen',
#    'contributions': 1,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/1494855?v=4',
#    'profile_url': 'https://api.github.com/users/jasonaowen',
#    'name': 'Jason Owen'},
#   {'repo': 'community',
#    'username': 'mveytsman',
#    'contributions': 1,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/34720?v=4',
#    'profile_url': 'https://api.github.com/users/mveytsman',
#    'name': 'Max Veytsman'},
#   {'repo': 'community',
#    'username': 'Will-Sommers',
#    'contributions': 1,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/1354217?v=4',
#    'profile_url': 'https://api.github.com/users/Will-Sommers',
#    'name': 'Will Sommers'}],
#  [{'repo': 'terminal_snake',
#    'username': 'kuanb',
#    'contributions': 2,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/6053396?v=4',
#    'profile_url': 'https://api.github.com/users/kuanb',
#    'name': 'Kuan Butts'},
#   {'repo': 'terminal_snake',
#    'username': 'renschler',
#    'contributions': 2,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/3973468?v=4',
#    'profile_url': 'https://api.github.com/users/renschler',
#    'name': 'Patrick Renschler'},
#   {'repo': 'terminal_snake',
#    'username': 'thomasballinger',
#    'contributions': 2,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/458879?v=4',
#    'profile_url': 'https://api.github.com/users/thomasballinger',
#    'name': 'Thomas Ballinger'},
#   {'repo': 'terminal_snake',
#    'username': 'margo73465',
#    'contributions': 1,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/3092855?v=4',
#    'profile_url': 'https://api.github.com/users/margo73465',
#    'name': 'Margo'}],
#  [{'repo': 'sprockets-commonjs',
#    'username': 'maccman',
#    'contributions': 33,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/2142?v=4',
#    'profile_url': 'https://api.github.com/users/maccman',
#    'name': 'Alex MacCaw'},
#   {'repo': 'sprockets-commonjs',
#    'username': 'josh',
#    'contributions': 2,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/137?v=4',
#    'profile_url': 'https://api.github.com/users/josh',
#    'name': 'Joshua Peek'},
#   {'repo': 'sprockets-commonjs',
#    'username': 'alex-stripe',
#    'contributions': 1,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/23127099?v=4',
#    'profile_url': 'https://api.github.com/users/alex-stripe',
#    'name': 'Alex Sexton'}],
#  [{'repo': 'proxy',
#    'username': 'zachallaun',
#    'contributions': 59,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/503938?v=4',
#    'profile_url': 'https://api.github.com/users/zachallaun',
#    'name': 'Zach Allaun'},
#   {'repo': 'proxy',
#    'username': 'davidbalbert',
#    'contributions': 58,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/123350?v=4',
#    'profile_url': 'https://api.github.com/users/davidbalbert',
#    'name': 'David Albert'}],
#  [{'repo': 'eventmachine',
#    'username': 'tmm1',
#    'contributions': 433,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/2567?v=4',
#    'profile_url': 'https://api.github.com/users/tmm1',
#    'name': 'Aman Gupta'},
#   {'repo': 'eventmachine',
#    'username': 'raggi',
#    'contributions': 98,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/348?v=4',
#    'profile_url': 'https://api.github.com/users/raggi',
#    'name': 'James Tucker'},
#   {'repo': 'eventmachine',
#    'username': 'jakedouglas',
#    'contributions': 53,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/18612?v=4',
#    'profile_url': 'https://api.github.com/users/jakedouglas',
#    'name': 'Jake Douglas'},
#   {'repo': 'eventmachine',
#    'username': 'sodabrew',
#    'contributions': 39,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/39406?v=4',
#    'profile_url': 'https://api.github.com/users/sodabrew',
#    'name': 'Aaron Stone'},
#   {'repo': 'eventmachine',
#    'username': 'igrigorik',
#    'contributions': 8,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/10652?v=4',
#    'profile_url': 'https://api.github.com/users/igrigorik',
#    'name': 'Ilya Grigorik'},
#   {'repo': 'eventmachine',
#    'username': 'smparkes',
#    'contributions': 7,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/4292?v=4',
#    'profile_url': 'https://api.github.com/users/smparkes',
#    'name': 'Steven Parkes'},
#   {'repo': 'eventmachine',
#    'username': 'dj2',
#    'contributions': 7,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/9611?v=4',
#    'profile_url': 'https://api.github.com/users/dj2',
#    'name': 'dan sinclair'},
#   {'repo': 'eventmachine',
#    'username': 'bklang',
#    'contributions': 4,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/167131?v=4',
#    'profile_url': 'https://api.github.com/users/bklang',
#    'name': 'Ben Klang'},
#   {'repo': 'eventmachine',
#    'username': 'davidsmalley',
#    'contributions': 4,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/644?v=4',
#    'profile_url': 'https://api.github.com/users/davidsmalley',
#    'name': 'David Smalley'},
#   {'repo': 'eventmachine',
#    'username': 'wyhaines',
#    'contributions': 4,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/12992?v=4',
#    'profile_url': 'https://api.github.com/users/wyhaines',
#    'name': 'Kirk Haines'},
#   {'repo': 'eventmachine',
#    'username': 'luislavena',
#    'contributions': 4,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/4182?v=4',
#    'profile_url': 'https://api.github.com/users/luislavena',
#    'name': 'Luis Lavena'},
#   {'repo': 'eventmachine',
#    'username': 'michaelklishin',
#    'contributions': 4,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/1090?v=4',
#    'profile_url': 'https://api.github.com/users/michaelklishin',
#    'name': 'Michael Klishin'},
#   {'repo': 'eventmachine',
#    'username': 'nolman',
#    'contributions': 4,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/22493?v=4',
#    'profile_url': 'https://api.github.com/users/nolman',
#    'name': 'Nolan Evans'},
#   {'repo': 'eventmachine',
#    'username': 'benburkert',
#    'contributions': 3,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/77?v=4',
#    'profile_url': 'https://api.github.com/users/benburkert',
#    'name': 'Ben Burkert'},
#   {'repo': 'eventmachine',
#    'username': 'deiv',
#    'contributions': 3,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/685054?v=4',
#    'profile_url': 'https://api.github.com/users/deiv',
#    'name': 'David Suárez'},
#   {'repo': 'eventmachine',
#    'username': 'Flameeyes',
#    'contributions': 3,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/74834?v=4',
#    'profile_url': 'https://api.github.com/users/Flameeyes',
#    'name': 'Diego Elio Pettenò'},
#   {'repo': 'eventmachine',
#    'username': 'razielgn',
#    'contributions': 3,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/237493?v=4',
#    'profile_url': 'https://api.github.com/users/razielgn',
#    'name': 'Federico Ravasio'},
#   {'repo': 'eventmachine',
#    'username': 'josh',
#    'contributions': 3,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/137?v=4',
#    'profile_url': 'https://api.github.com/users/josh',
#    'name': 'Joshua Peek'},
#   {'repo': 'eventmachine',
#    'username': 'piki',
#    'contributions': 3,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/3660033?v=4',
#    'profile_url': 'https://api.github.com/users/piki',
#    'name': 'Patrick Reynolds'},
#   {'repo': 'eventmachine',
#    'username': 'paddor',
#    'contributions': 3,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/8876?v=4',
#    'profile_url': 'https://api.github.com/users/paddor',
#    'name': 'Patrik Wenger'},
#   {'repo': 'eventmachine',
#    'username': 'garbagecat',
#    'contributions': 3,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/12989?v=4',
#    'profile_url': 'https://api.github.com/users/garbagecat',
#    'name': 'Francis Cianfrocca'},
#   {'repo': 'eventmachine',
#    'username': 'hsbt',
#    'contributions': 3,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/12301?v=4',
#    'profile_url': 'https://api.github.com/users/hsbt',
#    'name': 'SHIBATA Hiroshi'},
#   {'repo': 'eventmachine',
#    'username': 'funny-falcon',
#    'contributions': 3,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/249427?v=4',
#    'profile_url': 'https://api.github.com/users/funny-falcon',
#    'name': 'Sokolov Yura'},
#   {'repo': 'eventmachine',
#    'username': 'gnufied',
#    'contributions': 3,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/278?v=4',
#    'profile_url': 'https://api.github.com/users/gnufied',
#    'name': 'Hemant Kumar'},
#   {'repo': 'eventmachine',
#    'username': 'phiggins',
#    'contributions': 3,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/22962?v=4',
#    'profile_url': 'https://api.github.com/users/phiggins',
#    'name': 'pete higgins'},
#   {'repo': 'eventmachine',
#    'username': 'AE9RB',
#    'contributions': 2,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/40563?v=4',
#    'profile_url': 'https://api.github.com/users/AE9RB',
#    'name': 'David Turnbull'},
#   {'repo': 'eventmachine',
#    'username': 'evan-stripe',
#    'contributions': 2,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/23093332?v=4',
#    'profile_url': 'https://api.github.com/users/evan-stripe',
#    'name': 'Evan Broder'},
#   {'repo': 'eventmachine',
#    'username': 'nahi',
#    'contributions': 2,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/44209?v=4',
#    'profile_url': 'https://api.github.com/users/nahi',
#    'name': 'Hiroshi Nakamura'},
#   {'repo': 'eventmachine',
#    'username': 'neilconway',
#    'contributions': 2,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/556208?v=4',
#    'profile_url': 'https://api.github.com/users/neilconway',
#    'name': 'Neil Conway'},
#   {'repo': 'eventmachine',
#    'username': 'renekalff',
#    'contributions': 2,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/939461?v=4',
#    'profile_url': 'https://api.github.com/users/renekalff',
#    'name': 'René Kalff'}],
#  [{'repo': 'heroku-buildpack-ruby',
#    'username': 'hone',
#    'contributions': 796,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/16457?v=4',
#    'profile_url': 'https://api.github.com/users/hone',
#    'name': 'Terence Lee'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'schneems',
#    'contributions': 239,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/59744?v=4',
#    'profile_url': 'https://api.github.com/users/schneems',
#    'name': 'Richard Schneeman'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'ddollar',
#    'contributions': 23,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/3308?v=4',
#    'profile_url': 'https://api.github.com/users/ddollar',
#    'name': 'David Dollar'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'jkutner',
#    'contributions': 15,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/1589?v=4',
#    'profile_url': 'https://api.github.com/users/jkutner',
#    'name': 'Joe Kutner'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'danp',
#    'contributions': 7,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/2182?v=4',
#    'profile_url': 'https://api.github.com/users/danp',
#    'name': 'Dan Peterson'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'catsby',
#    'contributions': 7,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/61721?v=4',
#    'profile_url': 'https://api.github.com/users/catsby',
#    'name': 'Clint'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'wuputah',
#    'contributions': 6,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/3321?v=4',
#    'profile_url': 'https://api.github.com/users/wuputah',
#    'name': 'JD'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'mikehale',
#    'contributions': 5,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/1583?v=4',
#    'profile_url': 'https://api.github.com/users/mikehale',
#    'name': 'Michael Hale'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'cyx',
#    'contributions': 4,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/2257?v=4',
#    'profile_url': 'https://api.github.com/users/cyx',
#    'name': 'Cyril David'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'mattgraham',
#    'contributions': 3,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/51578?v=4',
#    'profile_url': 'https://api.github.com/users/mattgraham',
#    'name': 'Matt Graham'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'DyegoCosta',
#    'contributions': 2,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/636899?v=4',
#    'profile_url': 'https://api.github.com/users/DyegoCosta',
#    'name': 'Dyego Costa'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'icco',
#    'contributions': 2,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/20201?v=4',
#    'profile_url': 'https://api.github.com/users/icco',
#    'name': 'Nat Welch'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'rcs',
#    'contributions': 2,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/44762?v=4',
#    'profile_url': 'https://api.github.com/users/rcs',
#    'name': 'Ryan Sorensen'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'indirect',
#    'contributions': 1,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/78?v=4',
#    'profile_url': 'https://api.github.com/users/indirect',
#    'name': 'André Arko'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'arthurnn',
#    'contributions': 1,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/833383?v=4',
#    'profile_url': 'https://api.github.com/users/arthurnn',
#    'name': 'Arthur Nogueira Neves'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'benizi',
#    'contributions': 1,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/188520?v=4',
#    'profile_url': 'https://api.github.com/users/benizi',
#    'name': 'Benjamin R. Haskell'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'cjolly',
#    'contributions': 1,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/10403?v=4',
#    'profile_url': 'https://api.github.com/users/cjolly',
#    'name': 'Chad Jolly'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'crohr',
#    'contributions': 1,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/6114?v=4',
#    'profile_url': 'https://api.github.com/users/crohr',
#    'name': 'Cyril Rohr'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'dgrizzanti',
#    'contributions': 1,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/2196244?v=4',
#    'profile_url': 'https://api.github.com/users/dgrizzanti',
#    'name': 'David Grizzanti'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'freeformz',
#    'contributions': 1,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/103?v=4',
#    'profile_url': 'https://api.github.com/users/freeformz',
#    'name': 'Edward Muller'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'xentek',
#    'contributions': 1,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/61488?v=4',
#    'profile_url': 'https://api.github.com/users/xentek',
#    'name': 'Eric Marden'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'gabrielg',
#    'contributions': 1,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/3902?v=4',
#    'profile_url': 'https://api.github.com/users/gabrielg',
#    'name': 'Gabriel Gironda'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'jvanbaarsen',
#    'contributions': 1,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/1362793?v=4',
#    'profile_url': 'https://api.github.com/users/jvanbaarsen',
#    'name': 'Jeroen van Baarsen'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'hynkle',
#    'contributions': 1,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/142821?v=4',
#    'profile_url': 'https://api.github.com/users/hynkle',
#    'name': 'Jonathan Hinkle'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'jkrall',
#    'contributions': 1,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/11402?v=4',
#    'profile_url': 'https://api.github.com/users/jkrall',
#    'name': 'Joshua Krall'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'Fitzsimmons',
#    'contributions': 1,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/418066?v=4',
#    'profile_url': 'https://api.github.com/users/Fitzsimmons',
#    'name': 'Justin Fitzsimmons'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'mmcgrana',
#    'contributions': 1,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/2432?v=4',
#    'profile_url': 'https://api.github.com/users/mmcgrana',
#    'name': 'Mark McGranaghan'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'nthj',
#    'contributions': 1,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/245869?v=4',
#    'profile_url': 'https://api.github.com/users/nthj',
#    'name': 'Nathaniel Jones'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'oguzbilgic',
#    'contributions': 1,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/144778?v=4',
#    'profile_url': 'https://api.github.com/users/oguzbilgic',
#    'name': 'Oguz Bilgic'},
#   {'repo': 'heroku-buildpack-ruby',
#    'username': 'sumbach',
#    'contributions': 1,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/11580?v=4',
#    'profile_url': 'https://api.github.com/users/sumbach',
#    'name': 'Sam Umbach'}],
#  [{'repo': 'sprockets',
#    'username': 'josh',
#    'contributions': 2399,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/137?v=4',
#    'profile_url': 'https://api.github.com/users/josh',
#    'name': 'Joshua Peek'},
#   {'repo': 'sprockets',
#    'username': 'sstephenson',
#    'contributions': 143,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/2603?v=4',
#    'profile_url': 'https://api.github.com/users/sstephenson',
#    'name': 'Sam Stephenson'},
#   {'repo': 'sprockets',
#    'username': 'tenderlove',
#    'contributions': 32,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/3124?v=4',
#    'profile_url': 'https://api.github.com/users/tenderlove',
#    'name': 'Aaron Patterson'},
#   {'repo': 'sprockets',
#    'username': 'rafaelfranca',
#    'contributions': 13,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/47848?v=4',
#    'profile_url': 'https://api.github.com/users/rafaelfranca',
#    'name': 'Rafael França'},
#   {'repo': 'sprockets',
#    'username': 'dgraham',
#    'contributions': 12,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/122102?v=4',
#    'profile_url': 'https://api.github.com/users/dgraham',
#    'name': 'David Graham'},
#   {'repo': 'sprockets',
#    'username': 'Andreis13',
#    'contributions': 6,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/4076570?v=4',
#    'profile_url': 'https://api.github.com/users/Andreis13',
#    'name': 'Andrei Istratii'},
#   {'repo': 'sprockets',
#    'username': 'joshk',
#    'contributions': 6,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/8701?v=4',
#    'profile_url': 'https://api.github.com/users/joshk',
#    'name': 'Josh Kalderimis'},
#   {'repo': 'sprockets',
#    'username': 'juddblair',
#    'contributions': 4,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/806432?v=4',
#    'profile_url': 'https://api.github.com/users/juddblair',
#    'name': 'Judd Blair'},
#   {'repo': 'sprockets',
#    'username': 'mastahyeti',
#    'contributions': 3,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/1144197?v=4',
#    'profile_url': 'https://api.github.com/users/mastahyeti',
#    'name': 'Ben Toews'},
#   {'repo': 'sprockets',
#    'username': 'hotchpotch',
#    'contributions': 3,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/3500?v=4',
#    'profile_url': 'https://api.github.com/users/hotchpotch',
#    'name': 'Yuichi Tateno (secon)'},
#   {'repo': 'sprockets',
#    'username': 'ixti',
#    'contributions': 2,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/94782?v=4',
#    'profile_url': 'https://api.github.com/users/ixti',
#    'name': 'Alexey Zapparov'},
#   {'repo': 'sprockets',
#    'username': 'elia',
#    'contributions': 2,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/1051?v=4',
#    'profile_url': 'https://api.github.com/users/elia',
#    'name': 'Elia Schito'},
#   {'repo': 'sprockets',
#    'username': 'sferik',
#    'contributions': 2,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/10308?v=4',
#    'profile_url': 'https://api.github.com/users/sferik',
#    'name': 'Erik Berlin'},
#   {'repo': 'sprockets',
#    'username': 'jackdempsey',
#    'contributions': 2,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/479?v=4',
#    'profile_url': 'https://api.github.com/users/jackdempsey',
#    'name': 'jack dempsey'},
#   {'repo': 'sprockets',
#    'username': 'mat813',
#    'contributions': 2,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/75783?v=4',
#    'profile_url': 'https://api.github.com/users/mat813',
#    'name': 'Mathieu Arnold'},
#   {'repo': 'sprockets',
#    'username': 'petebrowne',
#    'contributions': 2,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/23861?v=4',
#    'profile_url': 'https://api.github.com/users/petebrowne',
#    'name': 'Pete Browne'},
#   {'repo': 'sprockets',
#    'username': 'drogus',
#    'contributions': 2,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/5004?v=4',
#    'profile_url': 'https://api.github.com/users/drogus',
#    'name': 'Piotr Sarnacki'},
#   {'repo': 'sprockets',
#    'username': 'tiegz',
#    'contributions': 2,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/5054?v=4',
#    'profile_url': 'https://api.github.com/users/tiegz',
#    'name': 'Tieg Zaharia'},
#   {'repo': 'sprockets',
#    'username': 'fxn',
#    'contributions': 2,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/3387?v=4',
#    'profile_url': 'https://api.github.com/users/fxn',
#    'name': 'Xavier Noria'},
#   {'repo': 'sprockets',
#    'username': 'yoshiori',
#    'contributions': 2,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/78609?v=4',
#    'profile_url': 'https://api.github.com/users/yoshiori',
#    'name': 'Yoshiori SHOJI'},
#   {'repo': 'sprockets',
#    'username': 'schneems',
#    'contributions': 2,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/59744?v=4',
#    'profile_url': 'https://api.github.com/users/schneems',
#    'name': 'Richard Schneeman'},
#   {'repo': 'sprockets',
#    'username': 'sonnym',
#    'contributions': 2,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/194834?v=4',
#    'profile_url': 'https://api.github.com/users/sonnym',
#    'name': 'Sonny Michaud'},
#   {'repo': 'sprockets',
#    'username': 'aaronblohowiak',
#    'contributions': 1,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/29454?v=4',
#    'profile_url': 'https://api.github.com/users/aaronblohowiak',
#    'name': 'Aaron Blohowiak'},
#   {'repo': 'sprockets',
#    'username': 'seuros',
#    'contributions': 1,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/2394703?v=4',
#    'profile_url': 'https://api.github.com/users/seuros',
#    'name': 'Abdelkader Boudih'},
#   {'repo': 'sprockets',
#    'username': 'poporul',
#    'contributions': 1,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/434619?v=4',
#    'profile_url': 'https://api.github.com/users/poporul',
#    'name': 'Alexey Pokhozhaev'},
#   {'repo': 'sprockets',
#    'username': 'jeltz',
#    'contributions': 1,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/78469?v=4',
#    'profile_url': 'https://api.github.com/users/jeltz',
#    'name': 'Andreas Karlsson'},
#   {'repo': 'sprockets',
#    'username': 'ai',
#    'contributions': 1,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/19343?v=4',
#    'profile_url': 'https://api.github.com/users/ai',
#    'name': 'Andrey Sitnik'},
#   {'repo': 'sprockets',
#    'username': 'adomokos',
#    'contributions': 1,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/80530?v=4',
#    'profile_url': 'https://api.github.com/users/adomokos',
#    'name': 'Attila Domokos'},
#   {'repo': 'sprockets',
#    'username': 'cespare',
#    'contributions': 1,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/318501?v=4',
#    'profile_url': 'https://api.github.com/users/cespare',
#    'name': 'Caleb Spare'},
#   {'repo': 'sprockets',
#    'username': 'carlosantoniodasilva',
#    'contributions': 1,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/26328?v=4',
#    'profile_url': 'https://api.github.com/users/carlosantoniodasilva',
#    'name': 'Carlos Antonio da Silva'}],
#  [{'repo': 'recurse-lisp-workshop',
#    'username': 'jcoglan',
#    'contributions': 5,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/9265?v=4',
#    'profile_url': 'https://api.github.com/users/jcoglan',
#    'name': 'James Coglan'}],
#  [{'repo': 'RSVPBot',
#    'username': 'kokeshii',
#    'contributions': 103,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/218754?v=4',
#    'profile_url': 'https://api.github.com/users/kokeshii',
#    'name': 'Carlos Rey'},
#   {'repo': 'RSVPBot',
#    'username': 'davidbalbert',
#    'contributions': 84,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/123350?v=4',
#    'profile_url': 'https://api.github.com/users/davidbalbert',
#    'name': 'David Albert'},
#   {'repo': 'RSVPBot',
#    'username': 'alexandrinaw',
#    'contributions': 38,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/4393302?v=4',
#    'profile_url': 'https://api.github.com/users/alexandrinaw',
#    'name': None},
#   {'repo': 'RSVPBot',
#    'username': 'zachallaun',
#    'contributions': 32,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/503938?v=4',
#    'profile_url': 'https://api.github.com/users/zachallaun',
#    'name': 'Zach Allaun'},
#   {'repo': 'RSVPBot',
#    'username': 'jjst',
#    'contributions': 13,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/4924090?v=4',
#    'profile_url': 'https://api.github.com/users/jjst',
#    'name': 'Jérémie Jost'},
#   {'repo': 'RSVPBot',
#    'username': 'karamcnair',
#    'contributions': 8,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/8367204?v=4',
#    'profile_url': 'https://api.github.com/users/karamcnair',
#    'name': 'Kara'},
#   {'repo': 'RSVPBot',
#    'username': 'mrdrozdov',
#    'contributions': 5,
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/1575034?v=4',
#    'profile_url': 'https://api.github.com/users/mrdrozdov',
#    'name': 'Andrew Drozdov'},
#   {'repo': 'RSVPBot',
#    'username': 'vakila',
#    'contributions': 5,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/5424927?v=4',
#    'profile_url': 'https://api.github.com/users/vakila',
#    'name': 'Anjana Sofia Vakil'},
#   {'repo': 'RSVPBot',
#    'username': 'munyari',
#    'contributions': 5,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/5841072?v=4',
#    'profile_url': 'https://api.github.com/users/munyari',
#    'name': 'Panashe Fundira'},
#   {'repo': 'RSVPBot',
#    'username': 'pnasrat',
#    'contributions': 4,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/13798?v=4',
#    'profile_url': 'https://api.github.com/users/pnasrat',
#    'name': 'Pris Nasrat'},
#   {'repo': 'RSVPBot',
#    'username': 'meereeum',
#    'contributions': 3,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/7970350?v=4',
#    'profile_url': 'https://api.github.com/users/meereeum',
#    'name': 'Miriam Shiffman'},
#   {'repo': 'RSVPBot',
#    'username': 'ifo',
#    'contributions': 3,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/193046?v=4',
#    'profile_url': 'https://api.github.com/users/ifo',
#    'name': 'Steve McCarthy'},
#   {'repo': 'RSVPBot',
#    'username': 'bgilbert',
#    'contributions': 2,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/361374?v=4',
#    'profile_url': 'https://api.github.com/users/bgilbert',
#    'name': 'Benjamin Gilbert'},
#   {'repo': 'RSVPBot',
#    'username': 'zeusdeux',
#    'contributions': 2,
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/635512?v=4',
#    'profile_url': 'https://api.github.com/users/zeusdeux',
#    'name': 'Mudit Ameta'},
#   {'repo': 'RSVPBot',
#    'username': 'dalequi',
#    'contributions': 1,
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/38567874?v=4',
#    'profile_url': 'https://api.github.com/users/dalequi',
#    'name': 'David Lechón Quiñones'},
#   {'repo': 'RSVPBot',
#    'username': 'porterjamesj',
#    'contributions': 1,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/2532521?v=4',
#    'profile_url': 'https://api.github.com/users/porterjamesj',
#    'name': 'James J Porter'}],
#  [{'repo': 'ca-tools',
#    'username': 'davidbalbert',
#    'contributions': 11,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/123350?v=4',
#    'profile_url': 'https://api.github.com/users/davidbalbert',
#    'name': 'David Albert'},
#   {'repo': 'ca-tools',
#    'username': 'senk',
#    'contributions': 1,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/710568?v=4',
#    'profile_url': 'https://api.github.com/users/senk',
#    'name': 'Robin Naundorf'}],
#  [{'repo': 'coding-bee',
#    'username': 'mrcoles',
#    'contributions': 16,
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/136651?v=4',
#    'profile_url': 'https://api.github.com/users/mrcoles',
#    'name': 'Peter Coles'}]]

# %%
import pandas as pd

# %%
pd.read_csv('recursecenter.csv')
# Out:
#      repo  username  contributions  avatar_url  profile_url  name
# 0    repo  username  contributions  avatar_url  profile_url  name
# 1    repo  username  contributions  avatar_url  profile_url  name
# 2    repo  username  contributions  avatar_url  profile_url  name
# 3    repo  username  contributions  avatar_url  profile_url  name
# 4    repo  username  contributions  avatar_url  profile_url  name
# 5    repo  username  contributions  avatar_url  profile_url  name
# 6    repo  username  contributions  avatar_url  profile_url  name
# 7    repo  username  contributions  avatar_url  profile_url  name
# 8    repo  username  contributions  avatar_url  profile_url  name
# 9    repo  username  contributions  avatar_url  profile_url  name
# 10   repo  username  contributions  avatar_url  profile_url  name
# 11   repo  username  contributions  avatar_url  profile_url  name
# 12   repo  username  contributions  avatar_url  profile_url  name
# 13   repo  username  contributions  avatar_url  profile_url  name
# 14   repo  username  contributions  avatar_url  profile_url  name
# 15   repo  username  contributions  avatar_url  profile_url  name
# 16   repo  username  contributions  avatar_url  profile_url  name
# 17   repo  username  contributions  avatar_url  profile_url  name
# 18   repo  username  contributions  avatar_url  profile_url  name
# 19   repo  username  contributions  avatar_url  profile_url  name
# 20   repo  username  contributions  avatar_url  profile_url  name
# 21   repo  username  contributions  avatar_url  profile_url  name
# 22   repo  username  contributions  avatar_url  profile_url  name
# 23   repo  username  contributions  avatar_url  profile_url  name
# 24   repo  username  contributions  avatar_url  profile_url  name
# 25   repo  username  contributions  avatar_url  profile_url  name
# 26   repo  username  contributions  avatar_url  profile_url  name
# 27   repo  username  contributions  avatar_url  profile_url  name
# 28   repo  username  contributions  avatar_url  profile_url  name
# 29   repo  username  contributions  avatar_url  profile_url  name
# ..    ...       ...            ...         ...          ...   ...
# 130  repo  username  contributions  avatar_url  profile_url  name
# 131  repo  username  contributions  avatar_url  profile_url  name
# 132  repo  username  contributions  avatar_url  profile_url  name
# 133  repo  username  contributions  avatar_url  profile_url  name
# 134  repo  username  contributions  avatar_url  profile_url  name
# 135  repo  username  contributions  avatar_url  profile_url  name
# 136  repo  username  contributions  avatar_url  profile_url  name
# 137  repo  username  contributions  avatar_url  profile_url  name
# 138  repo  username  contributions  avatar_url  profile_url  name
# 139  repo  username  contributions  avatar_url  profile_url  name
# 140  repo  username  contributions  avatar_url  profile_url  name
# 141  repo  username  contributions  avatar_url  profile_url  name
# 142  repo  username  contributions  avatar_url  profile_url  name
# 143  repo  username  contributions  avatar_url  profile_url  name
# 144  repo  username  contributions  avatar_url  profile_url  name
# 145  repo  username  contributions  avatar_url  profile_url  name
# 146  repo  username  contributions  avatar_url  profile_url  name
# 147  repo  username  contributions  avatar_url  profile_url  name
# 148  repo  username  contributions  avatar_url  profile_url  name
# 149  repo  username  contributions  avatar_url  profile_url  name
# 150  repo  username  contributions  avatar_url  profile_url  name
# 151  repo  username  contributions  avatar_url  profile_url  name
# 152  repo  username  contributions  avatar_url  profile_url  name
# 153  repo  username  contributions  avatar_url  profile_url  name
# 154  repo  username  contributions  avatar_url  profile_url  name
# 155  repo  username  contributions  avatar_url  profile_url  name
# 156  repo  username  contributions  avatar_url  profile_url  name
# 157  repo  username  contributions  avatar_url  profile_url  name
# 158  repo  username  contributions  avatar_url  profile_url  name
# 159  repo  username  contributions  avatar_url  profile_url  name
#
# [160 rows x 6 columns]

# %% [markdown]
# ## Now we have the object let's try writing it in a different form

# %%
# def append_list_to_csv(mylist, output_file):
#     with open(output_file, 'a') as myfile:
#         wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
#         wr.writerow(mylist)

# %%
# ## This part isn't in the right format
#     print("Writing to file.")

#     file_name = "{}.csv".format(org)
#     flat_contributions = [item for sublist in all_org_contributions for item in sublist]
#     ## Do this row by row.
#     for item in flat_contributions:
#         append_list_to_csv(item, file_name)

# %%
# practice with test data
test_data = all_org_contributions[1]

# %%
type(test_data)
# Out:
# list

# %%
for item in test_data:
    print(item.values()
# Out:
# dict_values(['webstack.jl', 'danielmendel', 63, 'https://avatars3.githubusercontent.com/u/304202?v=4', 'https://api.github.com/users/danielmendel', 'Daniel Espeset'])
# dict_values(['webstack.jl', 'astrieanna', 36, 'https://avatars3.githubusercontent.com/u/1205394?v=4', 'https://api.github.com/users/astrieanna', 'Leah Hanson'])
# dict_values(['webstack.jl', 'zachallaun', 19, 'https://avatars0.githubusercontent.com/u/503938?v=4', 'https://api.github.com/users/zachallaun', 'Zach Allaun'])
# dict_values(['webstack.jl', 'chuckha', 8, 'https://avatars0.githubusercontent.com/u/98927?v=4', 'https://api.github.com/users/chuckha', 'Chuck Ha'])
# dict_values(['webstack.jl', 'ncollins', 4, 'https://avatars1.githubusercontent.com/u/607298?v=4', 'https://api.github.com/users/ncollins', 'Nick Collins'])
# dict_values(['webstack.jl', 'maxlikely', 3, 'https://avatars1.githubusercontent.com/u/1237055?v=4', 'https://api.github.com/users/maxlikely', 'David'])
# dict_values(['webstack.jl', 'StefanKarpinski', 2, 'https://avatars2.githubusercontent.com/u/153596?v=4', 'https://api.github.com/users/StefanKarpinski', 'Stefan Karpinski'])
# dict_values(['webstack.jl', 'jroes', 1, 'https://avatars0.githubusercontent.com/u/27847?v=4', 'https://api.github.com/users/jroes', 'Jonathan Roes'])

# %%
def append_list_to_csv(mylist, output_file):
    with open(output_file, 'a') as myfile:
        wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
        wr.writerow(mylist)

# %%
file_name = "test.csv"

# %%
for item in test_data:
    append_list_to_csv(item.values(), file_name)

# %%
pd.read_csv('test.csv')
# Out:
#    webstack.jl     danielmendel  63  \
# 0  webstack.jl       astrieanna  36
# 1  webstack.jl       zachallaun  19
# 2  webstack.jl          chuckha   8
# 3  webstack.jl         ncollins   4
# 4  webstack.jl        maxlikely   3
# 5  webstack.jl  StefanKarpinski   2
# 6  webstack.jl            jroes   1
#
#   https://avatars3.githubusercontent.com/u/304202?v=4  \
# 0  https://avatars3.githubusercontent.com/u/12053...
# 1  https://avatars0.githubusercontent.com/u/50393...
# 2  https://avatars0.githubusercontent.com/u/98927...
# 3  https://avatars1.githubusercontent.com/u/60729...
# 4  https://avatars1.githubusercontent.com/u/12370...
# 5  https://avatars2.githubusercontent.com/u/15359...
# 6  https://avatars0.githubusercontent.com/u/27847...
#
#       https://api.github.com/users/danielmendel    Daniel Espeset
# 0       https://api.github.com/users/astrieanna       Leah Hanson
# 1       https://api.github.com/users/zachallaun       Zach Allaun
# 2          https://api.github.com/users/chuckha          Chuck Ha
# 3         https://api.github.com/users/ncollins      Nick Collins
# 4        https://api.github.com/users/maxlikely             David
# 5  https://api.github.com/users/StefanKarpinski  Stefan Karpinski
# 6            https://api.github.com/users/jroes     Jonathan Roes

# %%
flat_contributions = [item for sublist in all_org_contributions for item in sublist]

# %%
file_name = 'test2.csv'

for item in flat_contributions:
    append_list_to_csv(item.values(), file_name)

# %%
df = pd.read_csv('test2.csv')

# %%
df.columns = ['repo', 'username', 'contributions', 'avatar_url', 'profile_url', 'real_name']

# %%
df.head()
# Out:
#           repo      username  contributions  \
# 0       hs-cli  davidbalbert              2
# 1  webstack.jl  danielmendel             63
# 2  webstack.jl    astrieanna             36
# 3  webstack.jl    zachallaun             19
# 4  webstack.jl       chuckha              8
#
#                                           avatar_url  \
# 0  https://avatars2.githubusercontent.com/u/12335...
# 1  https://avatars3.githubusercontent.com/u/30420...
# 2  https://avatars3.githubusercontent.com/u/12053...
# 3  https://avatars0.githubusercontent.com/u/50393...
# 4  https://avatars0.githubusercontent.com/u/98927...
#
#                                  profile_url       real_name
# 0  https://api.github.com/users/davidbalbert    David Albert
# 1  https://api.github.com/users/danielmendel  Daniel Espeset
# 2    https://api.github.com/users/astrieanna     Leah Hanson
# 3    https://api.github.com/users/zachallaun     Zach Allaun
# 4       https://api.github.com/users/chuckha        Chuck Ha
