# %% [markdown]
# # Parsing gender from names with an API

# %% [markdown]
# Genderize.io determines the gender of a first name. Use the API for analytics, ad targeting, user segmenting etc. It utilizes big datasets of information, from user profiles across major social networks and exposes this data through its API. The response includes a certainty factor as well.

# %%
import pandas as pd

# %%
# %load ../parse_gender.py
import requests
import json


api_url_base = 'https://api.genderize.io/'

def get_gender(firstname):
    request_url = '{}?name={}'.format(api_url_base, firstname)
    response = requests.get(request_url)
    
    if response.status_code == 200:
        return (response.json())
    else:
        print('[!] HTTP {0} looking up name [{1}]'.format(response.status_code, firstname))
        return None

# %% [markdown]
# ### Loading
# The load function below will need to be abstracted to load csv's from a list of names entered. Otherwise, this is ready to be made into a script.

# %%
df = pd.read_csv('../recursecenter.csv')

# %%
df.columns = ['repo', 'username', 'contributions', 'avatar_url', 'profile_url', 'real_name']

# %%
df.shape
# Out:
# (160, 6)

# %%
## Split first name from real_name, look up gender

gender_list = list()

for name in df['real_name'].unique():
    if type(name) == str: # don't call on NaN values (which are float - why?)
        first_name = name.split(' ')[0]
        gender_result = get_gender(first_name)
        gender_result['real_name'] = name # add real name back to dictionary
        gender_list.append(gender_result)

# %%
gender_df = pd.DataFrame(gender_list)

# %%
# Sanity check for data size
print(gender_df.shape)
print(df.shape)
# Out:
# (143, 5)
# (160, 6)

# %%
df = recurse

# %%
df2 = pd.merge(df, gender_df[['real_name', 'gender', 'probability']], 
               on='real_name', how='outer')
# important: outer join will preserve the NaN values for real_name that aren't in `gender`

# %%
df2.shape
# Out:
# (160, 8)

# %%
df2
# Out:
#                       repo              username  contributions  \
# 0                   hs-cli          davidbalbert              2
# 1             blaggregator          davidbalbert             12
# 2                community          davidbalbert            335
# 3                    proxy          davidbalbert             58
# 4                  RSVPBot          davidbalbert             84
# 5                 ca-tools          davidbalbert             11
# 6              webstack.jl          danielmendel             63
# 7              webstack.jl            astrieanna             36
# 8              webstack.jl            zachallaun             19
# 9             blaggregator            zachallaun              1
# 10               community            zachallaun            745
# 11                   proxy            zachallaun             59
# 12                 RSVPBot            zachallaun             32
# 13             webstack.jl               chuckha              8
# 14             webstack.jl              ncollins              4
# 15             webstack.jl             maxlikely              3
# 16             webstack.jl       StefanKarpinski              2
# 17             webstack.jl                 jroes              1
# 18            blaggregator                 sursh            278
# 19            blaggregator               kenyavs             10
# 20                 RSVPBot          alexandrinaw             38
# 21            blaggregator             punchagan            249
# 22            blaggregator             stanzheng              5
# 23            blaggregator               akaptur              3
# 24            blaggregator          porterjamesj              3
# 25                 RSVPBot          porterjamesj              1
# 26            blaggregator             santialbo              3
# 27            blaggregator               strugee              2
# 28               community               strugee              1
# 29            blaggregator                danluu              2
# ..                     ...                   ...            ...
# 130              sprockets                mat813              2
# 131              sprockets            petebrowne              2
# 132              sprockets                drogus              2
# 133              sprockets                 tiegz              2
# 134              sprockets                   fxn              2
# 135              sprockets              yoshiori              2
# 144  https://api.github.com/users/carlosantoniodasilva
# 145               https://api.github.com/users/jcoglan
# 146              https://api.github.com/users/kokeshii
# 147                  https://api.github.com/users/jjst
# 148            https://api.github.com/users/karamcnair
# 149             https://api.github.com/users/mrdrozdov
# 150                https://api.github.com/users/vakila
# 151               https://api.github.com/users/munyari
# 152               https://api.github.com/users/pnasrat
# 153              https://api.github.com/users/meereeum
# 154                   https://api.github.com/users/ifo
# 155              https://api.github.com/users/bgilbert
# 156              https://api.github.com/users/zeusdeux
# 157               https://api.github.com/users/dalequi
# 158                  https://api.github.com/users/senk
# 159               https://api.github.com/users/mrcoles
#
#                    real_name  gender  probability
# 0               David Albert    male         1.00
# 1               David Albert    male         1.00
# 2               David Albert    male         1.00
# 3               David Albert    male         1.00
# 4               David Albert    male         1.00
# 5               David Albert    male         1.00
# 6             Daniel Espeset    male         1.00
# 7                Leah Hanson  female         1.00
# 8                Zach Allaun    male         0.99
# 9                Zach Allaun    male         0.99
# 10               Zach Allaun    male         0.99
# 11               Zach Allaun    male         0.99
# 12               Zach Allaun    male         0.99
# 13                  Chuck Ha    male         0.99
# 14              Nick Collins    male         0.99
# 15                     David    male         1.00
# 16          Stefan Karpinski    male         1.00
# 17             Jonathan Roes    male         1.00
# 18                       NaN     NaN          NaN
# 19                       NaN     NaN          NaN
# 20                       NaN     NaN          NaN
# 21          Puneeth Chaganti    male         1.00
# 22             Stanley Zheng    male         0.96
# 23            Allison Kaptur  female         1.00
# 24            James J Porter    male         0.99
# 25            James J Porter    male         0.99
# 26                Santi Albo    male         0.85
# 27                 AJ Jordan    male         0.81
# 28                 AJ Jordan    male         0.81
# 29                   Dan Luu    male         0.98
# ..                       ...     ...          ...
# 130           Mathieu Arnold    male         1.00
# 131              Pete Browne    male         1.00
# 132           Piotr Sarnacki    male         1.00
# 133             Tieg Zaharia    None          NaN
# 134             Xavier Noria    male         0.99
# 135           Yoshiori SHOJI    None          NaN
# 136            Sonny Michaud    male         0.95
# 137          Aaron Blohowiak    male         1.00
# 138        Abdelkader Boudih    male         1.00
# 139        Alexey Pokhozhaev    male         1.00
# 140         Andreas Karlsson    male         1.00
# 141            Andrey Sitnik    male         0.99
# 142           Attila Domokos    male         1.00
# 143              Caleb Spare    male         0.99
# 144  Carlos Antonio da Silva    male         1.00
# 145             James Coglan    male         0.99
# 146               Carlos Rey    male         1.00
# 147             Jérémie Jost    male         1.00
# 148                     Kara  female         0.95
# 149           Andrew Drozdov    male         1.00
# 150       Anjana Sofia Vakil  female         1.00
# 151          Panashe Fundira    None          NaN
# 152              Pris Nasrat  female         1.00
# 153          Miriam Shiffman  female         1.00
# 154           Steve McCarthy    male         1.00
# 155         Benjamin Gilbert    male         1.00
# 156              Mudit Ameta    male         1.00
# 157    David Lechón Quiñones    male         1.00
# 158           Robin Naundorf  female         0.59
# 159              Peter Coles    male         1.00
#
# [160 rows x 8 columns]
