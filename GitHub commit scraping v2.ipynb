# %% [markdown]
# # GitHub commit scraping v.2

# %%
# %load get_repo_contributions.py
import json
import requests

api_url_base = 'https://api.github.com/'
headers = {'Content-Type': 'application/json',
           'User-Agent': 'request',
           'Accept': 'application/vnd.github.v3+json'}

def get_repos(orgname):
    api_url = '{}orgs/{}/repos'.format(api_url_base, orgname)

    response = requests.get(api_url, headers=headers)

    if response.status_code == 200:
        return (response.json())
    else:
        print('[!] HTTP {0} calling [{1}]'.format(response.status_code, api_url))
        return None


def get_contributors(repo):
    name = repo['name']
    contrib_url = repo['contributors_url']
    
    response = requests.get(contrib_url, headers=headers)

    if response.status_code == 200:
        return (
            # returns `contribution_response`
            {'name': name,
             'data': response.json()}
        )
    else:
        print('[!] HTTP {0} calling repo [{1}]'.format(response.status_code, contrib_url))
        return None


def build_contribution_list(contribution_response):
    all_repo_contributions = list()

    for i in range(0,len(contribution_response['data'])):
        ctr = dict()
        ctr["repo"] = contribution_response['name']
        ctr["username"] = contribution_response['data'][i]['login']
        ctr["contributions"] = contribution_response['data'][i]['contributions']
        all_repo_contributions.append(ctr)
    
    return all_repo_contributions


all_org_contributions = list()
    
def get_all_contributions(org):
    repos = get_repos(org)

    for repo in repos:
        contributors = get_contributors(repo)
        contribution_list = build_contribution_list(contributors)
        all_org_contributions.append(contribution_list)

# %%
get_all_contributions('recursecenter')
# Out:
# [!] HTTP 403 calling [https://api.github.com/orgs/recursecenter/repos]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-f855b7bec0a1> in <module>
# ----> 1 get_all_contributions('recursecenter')
#
# <ipython-input-15-dccc135523c1> in get_all_contributions(org)
#      55     repos = get_repos(org)
#      56
# ---> 57     for repo in repos:
#      58         contributors = get_contributors(repo)
#      59         contribution_list = build_contribution_list(contributors)
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# ### Let's modify to use Tor.
# https://medium.com/@jasonrigden/using-tor-with-the-python-request-library-79015b2606cb

# %%
session = requests.session()
session.proxies = {}

session.proxies['http'] = 'socks5h://localhost:9050'
session.proxies['https'] = 'socks5h://localhost:9050'

# %%
r = session.get('http://httpbin.org/ip')
print(r.text)
# Out:
# {
#   "origin": "185.220.102.7, 185.220.102.7"
# }

# %%
api_url_base = 'https://api.github.com/'
headers = {'Content-Type': 'application/json',
           'User-Agent': 'python-requests/2.18.4',
           'Accept': 'application/vnd.github.v3+json'}

def get_repos(orgname):
    api_url = '{}orgs/{}/repos'.format(api_url_base, orgname)

    response = session.get(api_url, headers=headers)

    if response.status_code == 200:
        return (response.json())
    else:
        print('[!] HTTP {0} calling [{1}]'.format(response.status_code, api_url))
        return None


def get_contributors(repo):
    name = repo['name']
    contrib_url = repo['contributors_url']
    
    response = session.get(contrib_url, headers=headers)

    if response.status_code == 200:
        return (
            # returns `contribution_response`
            {'name': name,
             'data': response.json()}
        )
    else:
        print('[!] HTTP {0} calling repo [{1}]'.format(response.status_code, contrib_url))
        return None


def build_contribution_list(contribution_response):
    all_repo_contributions = list()

    for i in range(0,len(contribution_response['data'])):
        ctr = dict()
        ctr["repo"] = contribution_response['name']
        ctr["username"] = contribution_response['data'][i]['login']
        ctr["contributions"] = contribution_response['data'][i]['contributions']
        all_repo_contributions.append(ctr)
    
    return all_repo_contributions


all_org_contributions = list()
    
def get_all_contributions(org):
    repos = get_repos(org)

    for repo in repos:
        contributors = get_contributors(repo)
        contribution_list = build_contribution_list(contributors)
        all_org_contributions.append(contribution_list)

# %%
get_all_contributions('recursecenter')

# %%
import pandas as pd

# %%
# Need to flatten all_org_contributions for it to work
flat_contributions = [item for sublist in all_org_contributions for item in sublist]

# %%
df = pd.DataFrame(flat_contributions)

df.head()
# Out:
#    contributions         repo      username
# 0             51       hs-cli    zachallaun
# 1              2       hs-cli  davidbalbert
# 2             63  webstack.jl  danielmendel
# 3             36  webstack.jl    astrieanna
# 4             19  webstack.jl    zachallaun

# %%
df.pivot_table(index='username', values='contributions') \
    .sort_values(by='contributions', ascending=False)
# Out:
#                       contributions
# username
# josh                     801.333333
# hone                     796.000000
# tmm1                     433.000000
# sursh                    278.000000
# punchagan                249.000000
# zachallaun               151.166667
# sstephenson              143.000000
# schneems                 120.500000
# kokeshii                 103.000000
# raggi                     98.000000
# davidbalbert              82.833333
# danielmendel              63.000000
# madhuvishy                63.000000
# surenm                    61.000000
# jakedouglas               53.000000
# sodabrew                  39.000000
# alexandrinaw              38.000000
# astrieanna                36.000000
# maccman                   33.000000
# tenderlove                32.000000
# ddollar                   23.000000
# mrcoles                   16.000000
# jkutner                   15.000000
# jjst                      13.000000
# rafaelfranca              13.000000
# dgraham                   12.000000
# jollysonali               11.000000
# kenyavs                   10.000000
# chuckha                    8.000000
# igrigorik                  8.000000
# ...                             ...
# thomasboyt                 1.000000
# jkrall                     1.000000
# Will-Sommers               1.000000
# jvanbaarsen                1.000000
# HiroAgustin                1.000000
# xentek                     1.000000
# Fitzsimmons                1.000000
# margo73465                 1.000000
# mveytsman                  1.000000
# carlosantoniodasilva       1.000000
# indirect                   1.000000
# cespare                    1.000000
# nthj                       1.000000
# hynkle                     1.000000
# graue                      1.000000
# gabrielg                   1.000000
# poporul                    1.000000
# freeformz                  1.000000
# nnja                       1.000000
# esommer                    1.000000
# jasonaowen                 1.000000
# jeltz                      1.000000
# dgrizzanti                 1.000000
# mmcgrana                   1.000000
# dalequi                    1.000000
# crohr                      1.000000
# cjolly                     1.000000
# senk                       1.000000
# seuros                     1.000000
# jroes                      1.000000
#
# [146 rows x 1 columns]
